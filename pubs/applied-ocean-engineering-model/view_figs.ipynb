# %%
import glob
from IPython.display import display, PDF

pdf_files = sorted(glob.glob('pubs/applied-ocean-engineering-model/figs/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    display(PDF(pdf_path))
