# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('figs/from-matlab/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    page = doc[0]
    
    im = page.get_pixmap()
    display(Image(im.tobytes()))
# Out:
# figs/from-matlab/RM3_image.pdf
# figs/from-matlab/control_analysis_flowcharts.pdf
# figs/from-matlab/delta_x.pdf
# figs/from-matlab/experiments_ratios.pdf
# figs/from-matlab/graphical_abstract_optim.pdf
# figs/from-matlab/lagrange_multipliers.pdf
# figs/from-matlab/methodology_flowchart.pdf
# figs/from-matlab/multistart_bar_chart.pdf
# figs/from-matlab/multistart_convergence_tree.pdf
# figs/from-matlab/multistart_parallel_coordinates.pdf
# figs/from-matlab/optimization_flowchart.pdf
# figs/from-matlab/overlaid_geometry.pdf
# figs/from-matlab/overlaid_hydro_coeffs.pdf
# figs/from-matlab/pareto_constraint_activity_reactive.pdf
# figs/from-matlab/pareto_front_LCOE_contours.pdf
# figs/from-matlab/pareto_front_with_design_images.pdf
# figs/from-matlab/pareto_heuristics.pdf
# figs/from-matlab/post_optim_design_grid.pdf
# figs/from-matlab/post_optim_re_optim_objective_grid.pdf
# figs/from-matlab/probability_CDF.pdf
# figs/from-matlab/re_optim_design_grid.pdf
# figs/from-matlab/re_optim_design_tornado_J1.pdf
# figs/from-matlab/re_optim_design_tornado_J2.pdf
# figs/from-matlab/re_optim_objective_tornado.pdf
# figs/from-matlab/runtime_bar_chart.pdf
# figs/from-matlab/single_obj_convergence.pdf
# figs/from-matlab/single_obj_opt_power_matrix.pdf
# figs/from-matlab/sweep_num_seeds.pdf
# figs/from-matlab/xdsm.pdf
