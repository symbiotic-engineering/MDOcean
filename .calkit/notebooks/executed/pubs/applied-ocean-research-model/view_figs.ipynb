# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('figs/from-matlab/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    page = doc[0]
    
    im = page.get_pixmap()
    display(Image(im.tobytes()))
# Out:
# figs/from-matlab/FBD.pdf
# figs/from-matlab/MEEM_geometry.pdf
# figs/from-matlab/RM3_image.pdf
# figs/from-matlab/asymptotic_b_vector.pdf
# figs/from-matlab/case4_v1_auto_semilogx_khRxRpa4b_fv1.pdf
# figs/from-matlab/control_analysis_flowcharts.pdf
# figs/from-matlab/cost_vs_N_WEC.pdf
# figs/from-matlab/ctrl_polar_plot.pdf
# figs/from-matlab/damping_plate_aspect_ratio.pdf
# figs/from-matlab/damping_plate_deflection.pdf
# figs/from-matlab/damping_plate_flowchart.pdf
# figs/from-matlab/damping_plate_moment.pdf
# figs/from-matlab/dimensions.pdf
# figs/from-matlab/drag_convergence.pdf
# figs/from-matlab/drag_desc_fcn.pdf
# figs/from-matlab/drag_integral_B.pdf
# figs/from-matlab/drag_integral_G_m.pdf
# figs/from-matlab/drag_integral_G_p.pdf
# figs/from-matlab/dynamics_runtime.pdf
# figs/from-matlab/equivalent_stiffness.pdf
# figs/from-matlab/experiments_ratios.pdf
# figs/from-matlab/graphical_abstract_modeling.pdf
# figs/from-matlab/hydro_coeff_err.pdf
# ...
