# %%
import glob
import pymupdf
from IPython.display import IFrame

pdf_files = sorted(glob.glob('../../pubs/applied-ocean-research-model/figs/from-matlab/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    IFrame(pdf_path,width=600,height=400)
# Out:
# ../../pubs/applied-ocean-research-model/figs/from-matlab/FBD.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/MEEM_geometry.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/RM3_image.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/asymptotic_b_vector.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/control_analysis_flowcharts.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/cost_vs_N_WEC.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/damping_plate_aspect_ratio.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/damping_plate_deflection.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/damping_plate_flowchart.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/damping_plate_moment.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/dimensions.pdf
# ../../pubs/applied-ocean-research-model/figs/from-matlab/drag_convergence.pdf
# ...

# %%
from IPython.display import display_pdf
with open("../../pubs/applied-ocean-research-model/figs/from-matlab/FBD.pdf", "rb") as f:
    display_pdf(f.read(), raw=True)
