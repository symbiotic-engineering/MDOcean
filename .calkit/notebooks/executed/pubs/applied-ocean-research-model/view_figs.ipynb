# %%
import glob
from IPython.display import IFrame

pdf_files = sorted(glob.glob('pubs/applied-ocean-research-model/figs/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    IFrame(pdf_path,width=600,height=400)
