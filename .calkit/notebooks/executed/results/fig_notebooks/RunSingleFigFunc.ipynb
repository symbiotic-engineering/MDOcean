# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../RunSingleFigFunc/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../RunSingleFigFunc/ctrl_polar_plot_gamma.pdf
# ../RunSingleFigFunc/ctrl_polar_plot_mult.pdf
# ../RunSingleFigFunc/drag_convergence.pdf
# ../RunSingleFigFunc/nominal_geometry_viz.pdf
# ../RunSingleFigFunc/nominal_power_matrix.pdf
# ../RunSingleFigFunc/nominal_power_pdf.pdf
# ../RunSingleFigFunc/qcqp_circles_nominal.pdf
# ../RunSingleFigFunc/qcqp_circles_overlay.pdf
# ../RunSingleFigFunc/slamming_model_comparison_float.pdf
# ../RunSingleFigFunc/slamming_model_comparison_spar.pdf
