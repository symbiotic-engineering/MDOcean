# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../Validation/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../Validation/cost_vs_N_WEC.pdf
