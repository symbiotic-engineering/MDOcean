# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../Meem/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../Meem/asymptotic_b_vector.pdf
# ../Meem/meem_convergence_vs_NMK.pdf
# ../Meem/meem_convergence_vs_omega.pdf
# ../Meem/meem_matching.pdf
# ../Meem/meem_sparsity.pdf
# ../Meem/meem_validation.pdf
