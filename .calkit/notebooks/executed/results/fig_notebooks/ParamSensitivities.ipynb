# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../ParamSensitivities/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../ParamSensitivities/nonlinear_design_J1.pdf
# ../ParamSensitivities/nonlinear_design_J2.pdf
# ../ParamSensitivities/nonlinear_objectives.pdf
# ../ParamSensitivities/post_optim_constraint_grid.pdf
# ../ParamSensitivities/post_optim_design_grid.pdf
# ../ParamSensitivities/post_optim_re_optim_objective_grid.pdf
# ../ParamSensitivities/re_optim_constraint_grid.pdf
# ../ParamSensitivities/re_optim_design_grid.pdf
# ../ParamSensitivities/re_optim_design_tornado_J1.pdf
# ../ParamSensitivities/re_optim_design_tornado_J2.pdf
# ../ParamSensitivities/re_optim_design_tornado_x1.pdf
# ../ParamSensitivities/re_optim_design_tornado_x10.pdf
# ../ParamSensitivities/re_optim_design_tornado_x11.pdf
# ../ParamSensitivities/re_optim_design_tornado_x12.pdf
# ../ParamSensitivities/re_optim_design_tornado_x2.pdf
# ../ParamSensitivities/re_optim_design_tornado_x3.pdf
# ../ParamSensitivities/re_optim_design_tornado_x4.pdf
# ../ParamSensitivities/re_optim_design_tornado_x5.pdf
# ...
