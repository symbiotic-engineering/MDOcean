# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../ReadNonMatlabFigs/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../ReadNonMatlabFigs/FBD.pdf
# ../ReadNonMatlabFigs/MEEM_geometry.pdf
# ../ReadNonMatlabFigs/RM3_image.pdf
# ../ReadNonMatlabFigs/control_analysis_flowcharts.pdf
# ../ReadNonMatlabFigs/damping_plate_flowchart.pdf
# ../ReadNonMatlabFigs/dimensions.pdf
# ../ReadNonMatlabFigs/equivalent_stiffness.pdf
# ../ReadNonMatlabFigs/graphical_abstract_modeling.pdf
# ../ReadNonMatlabFigs/graphical_abstract_optim.pdf
# ../ReadNonMatlabFigs/methodology_flowchart.pdf
# ../ReadNonMatlabFigs/optimization_flowchart.pdf
# ../ReadNonMatlabFigs/section_flow.pdf
# ../ReadNonMatlabFigs/sim_runtime.pdf
# ../ReadNonMatlabFigs/taxonomy.pdf
# ../ReadNonMatlabFigs/trapezoid.pdf
# ../ReadNonMatlabFigs/xdsm.pdf
