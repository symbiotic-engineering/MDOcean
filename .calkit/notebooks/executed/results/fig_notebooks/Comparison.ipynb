# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../Comparison/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../Comparison/comparison_power_matrix.pdf
# ../Comparison/overlaid_geometry.pdf
# ../Comparison/overlaid_hydro_coeffs.pdf
# ../Comparison/probability_CDF.pdf
# ../Comparison/stacked_optimal_design_vars.pdf
# ../Comparison/stacked_optimal_outputs.pdf
