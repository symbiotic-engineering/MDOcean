# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../ParetoFigFunc/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../ParetoFigFunc/pareto_constraint_activity_damping.pdf
# ../ParetoFigFunc/pareto_constraint_activity_reactive.pdf
# ../ParetoFigFunc/pareto_front_LCOE_contours.pdf
# ../ParetoFigFunc/pareto_front_with_design_images.pdf
# ../ParetoFigFunc/pareto_heuristics.pdf
# ../ParetoFigFunc/pareto_heuristics_lcoe_tangent_contours.pdf
# ../ParetoFigFunc/pareto_heuristics_nondimensional.pdf
