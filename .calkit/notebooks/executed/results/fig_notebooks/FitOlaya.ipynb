# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../FitOlaya/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    page = doc[0]
    
    im = page.get_pixmap()
    display(Image(im.tobytes()))
# Out:
# ../FitOlaya/case24_compare_line_kRb_fnorm.pdf
# ../FitOlaya/case2_line_khRxRp_f_over_RxRb_aH0.pdf
# ../FitOlaya/case2_line_khRxRp_f_over_RxRb_aH0_expe1.pdf
# ../FitOlaya/case2_line_khRxRp_f_over_RxRb_aH0_expe1e2.pdf
# ../FitOlaya/case2_line_khRxRp_f_over_RxRb_aH0_expe2.pdf
# ../FitOlaya/case2_line_khRxRp_f_over_a2.pdf
# ../FitOlaya/case2_line_khRxRp_f_over_a2H0.pdf
# ../FitOlaya/case2_line_khRxRp_fnorm.pdf
# ../FitOlaya/case2_line_khRxRpa2_f_over_RxRb_aH0_expe1.pdf
# ../FitOlaya/case2_line_khRxRpa2_f_over_a2.pdf
# ../FitOlaya/case4_sep_auto_lnkhRxRpa2b_lnf_H0_expe1_sqrtkh.pdf
# ../FitOlaya/case4_sep_coeffs_vs_alpha.pdf
# ../FitOlaya/case4_sep_coeffs_vs_beta.pdf
# ../FitOlaya/case4_sep_manual_khRxRpa2b_f_H0_expe1_sqrtkh.pdf
# ../FitOlaya/case4_sub_line_kRb_fnorm.pdf
# ../FitOlaya/case4_sub_line_khRxRp_f_H0_cosh_N0.pdf
# ../FitOlaya/case4_sub_line_khRxRp_fnorm.pdf
# ../FitOlaya/case4_sub_loglog_khRxRpb_f_H0_expe1.pdf
# ../FitOlaya/case4_sub_loglog_khRxRpb_f_H0_expe1_b2sqrtkh.pdf
# ...
