# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../SweepGeoms/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../SweepGeoms/factor_grid.pdf
# ../SweepGeoms/sweep_geoms_grid_scatter.pdf
# ../SweepGeoms/sweep_geoms_line.pdf
# ../SweepGeoms/sweep_geoms_line_cwr_a2.pdf
# ../SweepGeoms/sweep_geoms_line_cwr_sa.pdf
# ../SweepGeoms/sweep_geoms_line_cwr_vol.pdf
# ../SweepGeoms/sweep_geoms_parallel.pdf
# ../SweepGeoms/sweep_geoms_pareto.pdf
# ../SweepGeoms/sweep_geoms_pareto_nondim.pdf
# ../SweepGeoms/sweep_geoms_scatter.pdf
# ../SweepGeoms/sweep_geoms_scatter_cwr_a2.pdf
# ../SweepGeoms/sweep_geoms_scatter_cwr_sa.pdf
# ../SweepGeoms/sweep_geoms_scatter_cwr_vol.pdf
