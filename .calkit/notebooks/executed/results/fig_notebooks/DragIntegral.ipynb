# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../DragIntegral/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../DragIntegral/drag_integral_B.pdf
# ../DragIntegral/drag_integral_G_i.pdf
# ../DragIntegral/drag_integral_G_m.pdf
# ../DragIntegral/drag_integral_G_p.pdf
# ../DragIntegral/drag_integral_G_r.pdf
