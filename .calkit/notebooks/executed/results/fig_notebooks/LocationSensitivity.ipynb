# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../LocationSensitivity/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../LocationSensitivity/location_1_power_matrix.pdf
# ../LocationSensitivity/location_2_power_matrix.pdf
# ../LocationSensitivity/location_3_power_matrix.pdf
# ../LocationSensitivity/location_4_power_matrix.pdf
# ../LocationSensitivity/location_probability_PDF.pdf
