# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../GradientOptimFigFunc/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../GradientOptimFigFunc/delta_x.pdf
# ../GradientOptimFigFunc/lagrange_multipliers.pdf
# ../GradientOptimFigFunc/single_obj_convergence.pdf
# ../GradientOptimFigFunc/single_obj_opt_geometry.pdf
# ../GradientOptimFigFunc/single_obj_opt_power_matrix.pdf
