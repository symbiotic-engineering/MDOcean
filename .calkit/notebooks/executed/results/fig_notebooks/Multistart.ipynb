# %%
import glob
import fitz
from IPython.display import Image, display

pdf_files = sorted(glob.glob('../Multistart/*.pdf'))

for pdf_path in pdf_files:
    print(pdf_path)
    doc = fitz.open(pdf_path)
    for page in doc:
        im = page.get_pixmap()
        display(Image(im.tobytes()))
    doc.close()
# Out:
# ../Multistart/multistart_bar_chart.pdf
# ../Multistart/multistart_convergence_tree.pdf
# ../Multistart/multistart_parallel_coordinates.pdf
